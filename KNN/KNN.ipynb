# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
plt.style.use('seaborn')

# %%
dfx = pd.read_csv('knn_X_data.csv')
dfy = pd.read_csv('knn_Y_data.csv')

x = dfx.values[:,1:-1]
y = dfy.values[:,1:-1]

y = y.reshape((-1,))
x.shape,y.shape
# Out:
# ((399, 2), (399,))

# %%
plt.scatter(x[:,0],x[:,1],c=y)
plt.show()

# %%
query_point = np.array([0,4])
plt.scatter(x[:,0],x[:,1],c=y)
plt.scatter(query_point[0],query_point[1],color = 'r')
plt.show()

# %% [markdown]
# #  ALGORITHM

# %%
# Function to find distance b/w two points
def dist(x1,x2):
    return np.sqrt(np.sum((x1-x2)**2))

def knn(x,y,query_point,k=5):
    vals = []
    m = x.shape[0]
    
#     this loop finds distance from all the  points 
    for i in range(m):
        d = dist(query_point,x[i])
        vals.append((d,y[i]))
        
#     sorting is done so that all the distances can be arranged in sorted order
    vals = sorted(vals)
    
#     Neatest K points
    vals = vals[:k]
    vals = np.array(vals)
    
    new_vals = np.unique(vals[:,1],return_counts=True)
    
#     max freq val
    print(" QueryPoint belongs to class " , new_vals[1].argmax())
    
    print(new_vals)
    print(vals)

# %%
knn(x,y,query_point)
# Out:
#  QueryPoint belongs to class  0
# (array([0., 1.]), array([4, 1], dtype=int64))
# [[1.11629431 0.        ]
#  [1.22555507 1.        ]
#  [1.25575518 0.        ]
#  [1.2619492  0.        ]
#  [1.42823963 0.        ]]
